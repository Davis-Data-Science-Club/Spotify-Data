# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv("songs_normalize[1].csv")

# %%
df.head()
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# ...

# %%
df.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667437     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512435     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
df.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
df.shape
# Out:
# (2000, 18)

# %%
df.loc[0:4]
# Out:
#            artist                    song  duration_ms  explicit  year  \
# 0  Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1       blink-182    All The Small Things       167066     False  1999
# 2      Faith Hill                 Breathe       250546     False  1999
# 3        Bon Jovi            It's My Life       224493     False  2000
# 4          *NSYNC             Bye Bye Bye       200560     False  2000
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 1          79         0.434   0.897    0    -4.918     1       0.0488
# 2          66         0.529   0.496    7    -9.007     1       0.0290
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
#
#    acousticness  instrumentalness  liveness  valence    tempo         genre
# ...

# %%
df.loc[100:105,["artist","explicit"]]
# Out:
#                  artist  explicit
# 100              Shaggy     False
# 101     Destiny's Child     False
# 102              Eminem      True
# 103       Kylie Minogue     False
# 104  Christina Aguilera     False
# 105       Nelly Furtado     False

# %%
df.iloc[0:5,0:3]
# Out:
#            artist                    song  duration_ms
# 0  Britney Spears  Oops!...I Did It Again       211160
# 1       blink-182    All The Small Things       167066
# 2      Faith Hill                 Breathe       250546
# 3        Bon Jovi            It's My Life       224493
# 4          *NSYNC             Bye Bye Bye       200560

# %%
df['song']
# Out:
# 0                       Oops!...I Did It Again
# 1                         All The Small Things
# 2                                      Breathe
# 3                                 It's My Life
# 4                                  Bye Bye Bye
#                          ...
# 1995                                    Sucker
# 1996                              Cruel Summer
# 1997                                The Git Up
# 1998    Dancing With A Stranger (with Normani)
# 1999                                   Circles
# Name: song, Length: 2000, dtype: object

# %%
sum(df['artist']=='Britney Spears')
# Out:
# 19

# %%
df.loc[df['artist']=='Britney Spears']
#df[df['artist']=='Britney Spears']
# Out:
#               artist                                               song  \
# 0     Britney Spears                             Oops!...I Did It Again
# 34    Britney Spears                             Born to Make You Happy
# 98    Britney Spears                                              Lucky
# 111   Britney Spears                                    I'm a Slave 4 U
# 223   Britney Spears                         Overprotected - Radio Edit
# 278   Britney Spears                    I'm Not a Girl, Not Yet a Woman
# 326   Britney Spears  Me Against the Music (feat. Madonna) - LP Vers...
# 402   Britney Spears                                              Toxic
# 429   Britney Spears                                     My Prerogative
# 459   Britney Spears                                          Everytime
# 702   Britney Spears                                         Gimme More
# 813   Britney Spears                                      Break the Ice
# ...

# %%
df[df['danceability']>0.9]
# Out:
#              artist                 song  duration_ms  explicit  year  \
# 6            Eminem  The Real Slim Shady       284200      True  2000
# 19          Dr. Dre     The Next Episode       161506      True  1999
# 43          Dr. Dre     Forgot About Dre       222293      True  1999
# 79         Mystikal         Shake Ya Ass       256973      True  2000
# 114   Mary J. Blige        Family Affair       265866     False  2001
# ...             ...                  ...          ...       ...   ...
# 1931      Lil Nas X        Old Town Road       113000     False  2019
# 1948        Cardi B                Money       183527      True  2018
# 1966       Blueface             Thotiana       129264      True  2018
# 1968      AJ Tracey       Ladbroke Grove       190537     False  2019
# 1969  Billie Eilish        bury a friend       193143     False  2019
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
df.loc[(df['year']==2019) & (df['danceability']>0.9)]
# Out:
#              artist                   song  duration_ms  explicit  year  \
# 1918         Offset  Clout (feat. Cardi B)       205803      True  2019
# 1931      Lil Nas X          Old Town Road       113000     False  2019
# 1968      AJ Tracey         Ladbroke Grove       190537     False  2019
# 1969  Billie Eilish          bury a friend       193143     False  2019
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# 1918          68         0.919   0.622    1    -7.384     1       0.0997
# 1931          76         0.907   0.530    1    -6.112     1       0.1270
# 1968          69         0.903   0.839   11    -9.447     0       0.2080
# 1969          75         0.905   0.389    8   -14.505     1       0.3320
#
#       acousticness  instrumentalness  liveness  valence    tempo  \
# 1918        0.2280          0.000004     0.122    0.424  140.022
# 1931        0.0578          0.000002     0.101    0.507  135.998
# ...

# %%
df.loc[df['artist']=='Taylor Swift',['artist','song','popularity','year']]
# Out:
#             artist                      song  popularity  year
# 905   Taylor Swift                Love Story          74  2008
# 993   Taylor Swift        You Belong With Me          55  2008
# 1093  Taylor Swift          Back To December          65  2010
# 1258  Taylor Swift  I Knew You Were Trouble.          59  2012
# 1343  Taylor Swift  I Knew You Were Trouble.          76  2012
# 1393  Taylor Swift                        22          68  2012
# 1421  Taylor Swift                 Bad Blood          54  2014
# 1462  Taylor Swift                     Style          61  2014
# 1473  Taylor Swift              Shake It Off          79  2014
# 1510  Taylor Swift               Blank Space          82  2014
# 1518  Taylor Swift                 Bad Blood          70  2015
# 1535  Taylor Swift            Wildest Dreams          78  2014
# 1572  Taylor Swift                     Style          77  2014
# 1747  Taylor Swift  Look What You Made Me Do          76  2017
# ...

# %%
artists_i_like = ['Taylor Swift', 'Britney Spears', 'Lady Gaga']
df[df['artist'].isin(artists_i_like)]
# Out:
#               artist                                               song  \
# 0     Britney Spears                             Oops!...I Did It Again
# 34    Britney Spears                             Born to Make You Happy
# 98    Britney Spears                                              Lucky
# 111   Britney Spears                                    I'm a Slave 4 U
# 223   Britney Spears                         Overprotected - Radio Edit
# 278   Britney Spears                    I'm Not a Girl, Not Yet a Woman
# 326   Britney Spears  Me Against the Music (feat. Madonna) - LP Vers...
# 402   Britney Spears                                              Toxic
# 429   Britney Spears                                     My Prerogative
# 459   Britney Spears                                          Everytime
# 702   Britney Spears                                         Gimme More
# 813   Britney Spears                                      Break the Ice
# ...

# %%
df['artist'].str.startswith('A')
df[df['artist'].str.startswith('B')]
# Out:
#               artist                                               song  \
# 0     Britney Spears                             Oops!...I Did It Again
# 3           Bon Jovi                                       It's My Life
# 12      Bomfunk MC's                                         Freestyler
# 34    Britney Spears                             Born to Make You Happy
# 42           Bow Wow  Bounce With Me (feat. Xscape) - Edited Album V...
# ...              ...                                                ...
# 1960       Bad Bunny                                           Callaita
# 1966        Blueface                                           Thotiana
# 1969   Billie Eilish                                      bury a friend
# 1970             BTS                        Boy With Luv (feat. Halsey)
# 1997    Blanco Brown                                         The Git Up
#
#       duration_ms  explicit  year  popularity  danceability  energy  key  \
# ...

# %%
df.query("artist == 'Taylor Swift' and danceability > 0.5 and energy > 0.7")
# Out:
#             artist                      song  duration_ms  explicit  year  \
# 905   Taylor Swift                Love Story       236266     False  2008
# 993   Taylor Swift        You Belong With Me       231146     False  2008
# 1393  Taylor Swift                        22       232120     False  2012
# 1421  Taylor Swift                 Bad Blood       211933     False  2014
# 1462  Taylor Swift                     Style       231000     False  2014
# 1473  Taylor Swift              Shake It Off       219200     False  2014
# 1510  Taylor Swift               Blank Space       231826     False  2014
# 1572  Taylor Swift                     Style       231000     False  2014
# 1747  Taylor Swift  Look What You Made Me Do       211853     False  2017
# 1758  Taylor Swift          ...Ready For It?       208186     False  2017
# 1996  Taylor Swift              Cruel Summer       178426     False  2019
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
df.groupby('year').mean()
# Out:
#         duration_ms  explicit  popularity  danceability    energy       key  \
# year
# 1998  215466.000000  1.000000   49.000000      0.727000  0.445000  1.000000
# 1999  253384.631579  0.210526   64.921053      0.668974  0.738421  5.131579
# 2000  249993.067568  0.162162   58.554054      0.689824  0.748257  5.148649
# 2001  242450.064815  0.212963   59.407407      0.674130  0.724631  5.240741
# 2002  253549.077778  0.333333   62.400000      0.675244  0.722567  5.644444
# 2003  236334.639175  0.237113   58.793814      0.664876  0.701485  5.268041
# 2004  234039.843750  0.375000   58.427083      0.696833  0.734698  5.760417
# 2005  236514.288462  0.278846   61.759615      0.672923  0.701048  5.000000
# 2006  238148.400000  0.273684   57.389474      0.660863  0.705347  5.326316
# 2007  231749.904255  0.234043   59.925532      0.630521  0.767149  5.500000
# 2008  235675.247423  0.237113   63.721649      0.664186  0.752320  5.164948
# ...

# %%
df.groupby('year')['popularity'].mean().sort_values(ascending=False)
# Out:
# year
# 2018    70.850467
# 1999    64.921053
# 2008    63.721649
# 2019    63.011236
# 2002    62.400000
# 2005    61.759615
# 2009    61.535714
# 2010    60.747664
# 2012    60.556522
# 2007    59.925532
# 2001    59.407407
# 2014    59.384615
# 2003    58.793814
# 2011    58.565657
# 2000    58.554054
# 2004    58.427083
# 2015    57.747475
# 2006    57.389474
# 2013    54.786517
# 2016    54.171717
# 2017    53.882883
# 1998    49.000000
# 2020    43.333333
# Name: popularity, dtype: float64

# %%
df['artist'].value_counts()
# Out:
# Rihanna           25
# Drake             23
# Eminem            21
# Calvin Harris     20
# Britney Spears    19
#                   ..
# Sidney Samson      1
# Cam’ron            1
# Elvis Presley      1
# Lucenzo            1
# Blanco Brown       1
# Name: artist, Length: 835, dtype: int64

# %%
len(df['artist'].unique())
# Out:
# 835

# %%
df.sort_values('artist')
# Out:
#          artist                     song  duration_ms  explicit  year  \
# 86       *NSYNC         It's Gonna Be Me       191040     False  2000
# 4        *NSYNC              Bye Bye Bye       200560     False  2000
# 198      *NSYNC                     Gone       292000     False  2001
# 283      *NSYNC               Girlfriend       253600     False  2001
# 120         112            It's Over Now       264933     False  2001
# ...         ...                      ...          ...       ...   ...
# 308    t.A.T.u.  All The Things She Said       214440      True  2020
# 1214  will.i.am             This Is Love       279026     False  2013
# 1307  will.i.am           Scream & Shout       283400      True  2013
# 828   will.i.am             Heartbreaker       327880      True  2007
# 1315  will.i.am               #thatPOWER       279506     False  2013
#
#       popularity  danceability  energy  key  loudness  mode  speechiness  \
# ...

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.countplot(x='artist',data=df)
# Out:
# <AxesSubplot:xlabel='artist', ylabel='count'>

# %%
fig = px.histogram(df,x='genre',title='Distribution of Genre')
fig.update_xaxes(categoryorder = "total descending")
fig.update_xaxes(tickangle=-90)
fig.show()
# Out:
# <div>                            <div id="a9394bff-aef1-4b31-87bd-5ee264c4a57a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9394bff-aef1-4b31-87bd-5ee264c4a57a")) {                    Plotly.newPlot(                        "a9394bff-aef1-4b31-87bd-5ee264c4a57a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"genre=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["pop","rock, pop","pop, country","rock, metal","pop","hip hop, pop, R&B","hip hop","pop, rock","pop, R&B","Dance/Electronic","pop","pop","pop","rock, pop","pop, Dance/Electronic","hip hop, pop, R&B","pop","pop","pop","hip hop","roc
# ...

# %%
plt.figure(figsize=(15,8))
#sns.histplot(x='danceability',data=df)
#sns.histplot(df['danceability'])

#sns.histplot(x='danceability', data=df, binwidth=0.05)
#sns.histplot(x='danceability', data=df, bins=30)
sns.histplot(x='danceability', data=df, bins=20, kde=True, stat='density')
#kernel density estimate
# Out:
# <AxesSubplot:xlabel='danceability', ylabel='Density'>

# %%
fig = px.histogram(df,x='danceability', title="Distribution of Danceability", nbins=20)
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="1b1028aa-157d-414a-a7ed-501310ca74cc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b1028aa-157d-414a-a7ed-501310ca74cc")) {                    Plotly.newPlot(                        "1b1028aa-157d-414a-a7ed-501310ca74cc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"danceability=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":20,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0.751,0.434,0.529,0.551,0.614,0.706,0.949,0.708,0.713,0.72,0.617,0.745,0.822,0.586,0.689,0.797,0.761,0.671,0.74,0.922,0.556,0.801,0.634,0.656,0.522,0.425,0.528,0.879,0.682,0.644,0.51,0.85,0.736,0.839,0.633,0.813,
# ...

# %%
plt.figure(figsize=(15,8))
#sns.boxplot(data=df,x="year",y="danceability")
sns.violinplot(data=df,x="danceability")
# Out:
# <AxesSubplot:xlabel='danceability'>

# %%
fig = px.box(df, x="year", y="danceability", points="all")
fig.show()
# Out:
# <div>                            <div id="4be2e618-1047-4a69-a1b7-2d3e48bc6671" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4be2e618-1047-4a69-a1b7-2d3e48bc6671")) {                    Plotly.newPlot(                        "4be2e618-1047-4a69-a1b7-2d3e48bc6671",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"year=%{x}<br>danceability=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[2000,1999,1999,2000,2000,1999,2000,2000,1999,2001,2011,1999,2000,1999,1999,2002,1999,2000,1999,1999,2000,1999,2000,2000,1999,2000,2001,2000,2000,2016,1999,2000,2000,2000,1999,1999,2000,1999,2001,2000,1999,2000,2000,1999,1998,1999
# ...

# %%
df_year=df.groupby("year").mean().reset_index()
fig = px.line(df_year,x="year",y=["acousticness", "speechiness", "danceability", "energy", "instrumentalness", "liveness", "valence"])
fig.show()
# Out:
# <div>                            <div id="d01e5d50-3d10-4e4f-8b16-4b9be618be88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d01e5d50-3d10-4e4f-8b16-4b9be618be88")) {                    Plotly.newPlot(                        "d01e5d50-3d10-4e4f-8b16-4b9be618be88",                        [{"hovertemplate":"variable=acousticness<br>year=%{x}<br>value=%{y}<extra></extra>","legendgroup":"acousticness","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"acousticness","orientation":"v","showlegend":true,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x","y":[0.339,0.1436884605263158,0.1183389054054054,0.1450597962962963,0.14403338
# ...

# %%
plt.figure(figsize=(12,8))
plt.scatter(data=df,x='valence',y='danceability')
plt.xlabel("Valence",fontsize=15)
x=df["valence"]
y=df["danceability"]
x.corr(y)
#df["valence"].corr(df["danceability"])
# Out:
# 0.4031776456320266

# %%
fig=px.scatter(df,x="valence", y="danceability",title="Valence vs Danceability", size="acousticness")
